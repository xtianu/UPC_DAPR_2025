# %% [markdown]
# <a href="https://colab.research.google.com/github/xtianu/UPC_DAPR_2025/blob/main/S2/Examples/clustering_KMeans_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EXAMPLE: Clustering Iris**

# %%
from sklearn.cluster import KMeans
import seaborn as sns

iris = sns.load_dataset("iris")

X = iris[['sepal_length','sepal_width','petal_length','petal_width']] # features
y = iris['species'] # class labels

group = KMeans(n_clusters=3).fit_predict(X)

iris_grouped = iris
iris_grouped['kmeans'] = group
g = sns.pairplot(iris_grouped, hue="kmeans")
